# %% [markdown]
# Using the same nyc-ticket-violation dataset, let’s assume that tickets can be dismissed
# if the license plate, state, and/or street name are all there but without requiring the make of car.
# Remove rows that are missing one or more of these. How many rows remain? Assuming $100/ticket,
# how much money would the city lose as a result of this?

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('violations.csv')
df
# Out:
#        Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0          4714702166  KGK6659                 NY        PAS  11/12/2020
# 1          8793684599  L5232HY                 TN        PAS  09/14/2020
# 2          8864757053   BPMN76                 FL        PAS  11/25/2020
# 3          8778326047  57387MJ                 NY        COM  08/20/2020
# 4          4706640702   M81KFJ                 NJ        PAS  09/09/2020
# ...               ...      ...                ...        ...         ...
# 49995      4014245755  JPN4910                 NY        PAS  06/25/2020
# 49996      8794437506   174ZYG                 CT        PAS  08/25/2020
# 49997      8849769581  HES6895                 NY        PAS  11/03/2020
# 49998      8755448173  63035MN                 NY        COM  08/19/2020
# 49999      8581527528  AW74165                 CT        PAS  08/06/2020
#
#        Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
# Filter out rows with missing required fields
no_na_set_df = df.dropna(subset=['Plate ID', 'Registration State', 'Street Name'])
no_na_set_df
# Out:
#        Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0          4714702166  KGK6659                 NY        PAS  11/12/2020
# 1          8793684599  L5232HY                 TN        PAS  09/14/2020
# 2          8864757053   BPMN76                 FL        PAS  11/25/2020
# 3          8778326047  57387MJ                 NY        COM  08/20/2020
# 4          4706640702   M81KFJ                 NJ        PAS  09/09/2020
# ...               ...      ...                ...        ...         ...
# 49995      4014245755  JPN4910                 NY        PAS  06/25/2020
# 49996      8794437506   174ZYG                 CT        PAS  08/25/2020
# 49997      8849769581  HES6895                 NY        PAS  11/03/2020
# 49998      8755448173  63035MN                 NY        COM  08/19/2020
# 49999      8581527528  AW74165                 CT        PAS  08/06/2020
#
#        Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
no_na_set_df.isnull().sum()
# Out:
# Summons Number                           0
# Plate ID                                 0
# Registration State                       0
# Plate Type                               0
# Issue Date                               0
# Violation Code                           0
# Vehicle Body Type                      143
# Vehicle Make                           134
# Issuing Agency                           0
# Street Code1                             0
# Street Code2                             0
# Street Code3                             0
# Vehicle Expiration Date                  0
# Violation Location                   17890
# Violation Precinct                       0
# Issuer Precinct                          0
# Issuer Code                              0
# Issuer Command                       17857
# Issuer Squad                         17857
# Violation Time                           1
# Time First Observed                  48101
# Violation County                       111
# ...

# %%
no_na_set_df= df.dropna()
no_na_set_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Summons Number                     0 non-null      int64
#  1   Plate ID                           0 non-null      object
#  2   Registration State                 0 non-null      object
#  3   Plate Type                         0 non-null      object
#  4   Issue Date                         0 non-null      object
#  5   Violation Code                     0 non-null      int64
#  6   Vehicle Body Type                  0 non-null      object
#  7   Vehicle Make                       0 non-null      object
#  8   Issuing Agency                     0 non-null      object
#  9   Street Code1                       0 non-null      int64
#  10  Street Code2                       0 non-null      int64
# ...

# %%
print(".......................remaining rows.................................")
# Out:
# .......................remaining rows.................................

# %%
# Count the number of remaining rows
num_rows = len(df.index)
print(f' The number of  rows remaining {num_rows}')
# Out:
#  The number of  rows remaining 49990

# %%
print(".......................Amount remaining.................................")
# Out:
# .......................Amount remaining.................................

# %%
# Calculate the amount of money the city would lose
money_lost = num_rows * 100
print( f'The total amount of money remain is $ {money_lost}' )
# Out:
# The total amount of money remain is $ 4999000
